# %%
import pandas as pd
import openpyxl

# %%
wb = openpyxl.Workbook()

# %%
sheet =wb.active

# %%
b1 = sheet.cell(row = 1, column = 1)

# %%
b1.value= 'aahana'

# %%
b2 = sheet.cell(row= 1 , column = 2)

# %%
b2.value = 'khan'

# %%
b3 = sheet['A2']
b3.value = "tapashaya"

# %%
b4 = sheet['B2']
b4.value = "Raghuwanshi"

# %%
wb.save(r"C:\Users\selfk\OneDrive\Desktop\archive (3)\marksheet.csv")

# %%
df = pd.read_excel(r"C:\Users\selfk\OneDrive\Desktop\archive (3)\marksheet.csv")
df
# Out:
#       aahana         khan
# 0  tapashaya  Raghuwanshi

# %%
df1=pd.read_excel(r"C:\Users\selfk\OneDrive\Desktop\archive (5)\employee_data.xlsx")

# %%
df1.head()
# Out:
#   First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0     Aditi     Mishra  Female   35   80000        65000    15000
# 1       Sona     Singh  Female   35   70000        58000    12000
# 2       Devi    Thakur  Female   36   65000        60000     5000
# 3     Anjali      Kaur  Female   42   62000        50000    12000
# 4      Sahil  Deshmukh    Male   29   62000        57000     5000
#
#    Expenditure Percentage  Savings Percentage
# 0                0.812500            0.187500
# 1                0.828571            0.171429
# 2                0.923077            0.076923
# 3                0.806452            0.193548
# 4                0.919355            0.080645

# %%
#Convert data into different-2 sheets and share one excel
df2 = df1[df1['Gender'] == 'Female']

# %%
df2
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0      Aditi     Mishra  Female   35   80000        65000    15000
# 1        Sona     Singh  Female   35   70000        58000    12000
# 2        Devi    Thakur  Female   36   65000        60000     5000
# 3      Anjali      Kaur  Female   42   62000        50000    12000
# 6       Divya     Bhatt  Female   42   52500        47000     5500
# 8        Jaya     Mehta  Female   28   52000        46000     6000
# 9       Candy     Patel  Female   35   52000        40000    12000
# 14      Tulsi   Acharya  Female   40   45200        40000     5200
# 15    Jasleen      Kaur  Female   50   45000        40000     5000
# 19      Charu     Patil  Female   26   40000        35000     5000
# 25     Shaila     Gupta  Female   51   35000        34000     1000
# 26      Inaya    Kumari  Female   52   30000        20000    10000
# 31      Navi      Gupta  Female   51   25000        20000     5000
# ...

# %%
df3 = df1[df1['Savings Percentage'] >=0.104762]

# %%
df3
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0      Aditi     Mishra  Female   35   80000        65000    15000
# 1        Sona     Singh  Female   35   70000        58000    12000
# 3      Anjali      Kaur  Female   42   62000        50000    12000
# 7        Amar       Rao    Male   52   52100        46000     6100
# 8        Jaya     Mehta  Female   28   52000        46000     6000
# 9       Candy     Patel  Female   35   52000        40000    12000
# 13      Kanak     Patel    Male   45   50500        40000    10500
# 14      Tulsi   Acharya  Female   40   45200        40000     5200
# 15    Jasleen      Kaur  Female   50   45000        40000     5000
# 18    Atharva       Das    Male   29   41000        35000     6000
# 19      Charu     Patil  Female   26   40000        35000     5000
# 20       Ajay      Shah    Male   35   36000        32000     4000
# 21        Jai     Patil    Male   36   35500        30000     5500
# ...

# %%
with pd.ExcelWriter(r"C:\Users\selfk\OneDrive\Desktop\archive (5)\employee_data.xlsx") as writer:
    df2.to_excel(writer, sheet_name = 'Gender')
    df3.to_excel(writer, sheet_name = 'Savings Percentage')

# %%
df1 = pd.read_excel(r"C:\Users\selfk\OneDrive\Desktop\archive (5)\employee_data.xlsx", sheet_name= 'Gender')

# %%
df1
# Out:
#     Unnamed: 0.1  Unnamed: 0 First Name Last Name  Gender  Age  Salary  \
# 0              0           0     Aditi     Mishra  Female   35   80000
# 1              1           1       Sona     Singh  Female   35   70000
# 2              2           2       Devi    Thakur  Female   36   65000
# 3              3           3     Anjali      Kaur  Female   42   62000
# 4              4           6      Divya     Bhatt  Female   42   52500
# 5              5           8       Jaya     Mehta  Female   28   52000
# 6              6           9      Candy     Patel  Female   35   52000
# 7              7          14      Tulsi   Acharya  Female   40   45200
# 8              8          15    Jasleen      Kaur  Female   50   45000
# 9              9          19      Charu     Patil  Female   26   40000
# 10            10          25     Shaila     Gupta  Female   51   35000
# 11            11          26      Inaya    Kumari  Female   52   30000
# ...

# %%
df2 = pd.read_excel(r"C:\Users\selfk\OneDrive\Desktop\archive (5)\employee_data.xlsx", sheet_name= 'Savings Percentage')

df2.head()
# Out:
#    Unnamed: 0 First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0           0     Aditi     Mishra  Female   35   80000        65000    15000
# 1           1       Sona     Singh  Female   35   70000        58000    12000
# 2           3     Anjali      Kaur  Female   42   62000        50000    12000
# 3           7       Amar       Rao    Male   52   52100        46000     6100
# 4           8       Jaya     Mehta  Female   28   52000        46000     6000
#
#    Expenditure Percentage  Savings Percentage
# 0                0.812500            0.187500
# 1                0.828571            0.171429
# 2                0.806452            0.193548
# 3                0.882917            0.117083
# 4                0.884615            0.115385
