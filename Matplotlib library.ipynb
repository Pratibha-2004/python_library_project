# %%
import pandas as pd
import numpy as np 
import matplotlib as plt

# %%
df = pd.DataFrame(np.random.randn(300) , columns=['data'],index  = pd.date_range('2024/09/19',periods = 300))

# %%
df
# Out:
#                 data
# 2024-09-19  0.100564
# 2024-09-20 -1.205602
# 2024-09-21  0.344617
# 2024-09-22 -0.988537
# 2024-09-23 -1.447752
# ...              ...
# 2025-07-11 -0.904886
# 2025-07-12 -0.229941
# 2025-07-13  0.756840
# 2025-07-14  0.872808
# 2025-07-15 -1.301874
#
# [300 rows x 1 columns]

# %%
df.plot(figsize = (10,10))
# Out:
# <Axes: >

# %%
df = pd.read_excel(r"C:\Users\selfk\OneDrive\Desktop\Global Superstore1.xlsx")

# %%
df['Sales'].plot(figsize = (20,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind = 'bar',figsize = (20,10))
# Out:
# <Axes: >

# %%
df.iloc[[5]].plot(kind = 'barh',figsize = (20,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind = 'barh',figsize = (20,10))
# Out:
# <Axes: >

# %%
df.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sales'].plot(kind = 'hist',orientation = 'horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %%
df.hist(figsize=(20,10),color = 'y' , alpha = .9)
# Out:
# array([[<Axes: title={'center': 'Row ID'}>,
#         <Axes: title={'center': 'Order Date'}>,
#         <Axes: title={'center': 'Ship Date'}>],
#        [<Axes: title={'center': 'Postal Code'}>,
#         <Axes: title={'center': 'Sales'}>,
#         <Axes: title={'center': 'Quantity'}>],
#        [<Axes: title={'center': 'Discount'}>,
#         <Axes: title={'center': 'Profit'}>,
#         <Axes: title={'center': 'Shipping Cost'}>]], dtype=object)

# %%
df.plot(kind = 'box' ,figsize = (20,10),color = {'boxes' : 'g' , 'whiskers' :'r'} , vert = False )
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56430.500000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
df[['Sales','Quantity','Profit']].plot(kind = 'area' , figsize = (20,10), alpha = .4,stacked = False)
# Out:
# <Axes: >

# %%
df.plot.scatter(x = 'Sales' , y = 'Profit',c = 'Shipping Cost',s = df['Discount']*500)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
df.plot.scatter(x = 'Quantity' , y = 'Sales')
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>
